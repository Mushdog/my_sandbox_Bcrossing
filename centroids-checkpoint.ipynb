# %%
import pandas as pd
import numpy as np
from pprint import pprint

from utils import get_dfs, concat_output_filename, load_head_items
from prep_organized_boycotts import (
    group_by_age, group_by_gender, group_by_genre,
    group_by_occupation, group_by_power, group_by_state, group_by_genre_strict
)

# %%
dfs = get_dfs('bcrossing')
# Out:
# Path to ratings file is: /home/ec2-user/.surprise_data/bcrossing/bcrossing/ratings.csv

# %%
users_df = dfs['users']
ratings_df = dfs['ratings']
print(users_df.head())
print(ratings_df.head())


print(len(ratings_df.groupby('user_id')))
print(len(ratings_df.groupby('movie_id')))
# Out:
#        user_id   age country  state
# 48815    11676   NaN     n/a    NaN
# 81153    16877  37.0     usa    0.0
# 92472    20806   NaN     usa    0.0
# 95333    21356  56.0     usa    0.0
# 98536    22625  54.0     usa    0.0
#        user_id  movie_id  rating
# 48815    11676      9295     5.0
# 81153    16877      9295     4.5
# 92472    20806      9295     3.0
# 95333    21356      9295     3.5
# 98536    22625      9295     5.0
# 12293
# 13768

# %% [markdown]
# # Warning:
# The following cell is very slow, so it will save outputs into some_distances.json
#
# Therefore, you may wish to just skip running this cell unless something major has changed

# %%
from collections import defaultdict
from scipy.spatial.distance import cosine

groups = group_by_age(users_df) + group_by_state(users_df,'bcrossing')

#groups = group_by_gender(users_df)
groups += [{'name': 'all', 'df': users_df}]
movie_set = sorted(list(set(ratings_df.movie_id)))

user_to_vec = {}
group_to_implicit_vecs = defaultdict(list)
group_to_explicit_vecs = defaultdict(list)

group_to_num_ratings = defaultdict(int)

# we're gonna do a bunch of stuff at once
for group in groups:
    print(group['name'])
    
    # Get all the user ids in this boycott group (e.g. all Comedy fans or all users of a certain age range)
    group_uid_set = set(list(group['df'].user_id))
    
    for user_id in group_uid_set:
        # get all the ratings for this user
        user_ratings = ratings_df[ratings_df.user_id == user_id]
        user_movie_set = list(set(user_ratings.movie_id))
        
        implicit_vec = []
        explicit_vec = []
        for movie_id in movie_set:
            if movie_id in user_movie_set:
                implicit_vec.append(1)
                rating = user_ratings[user_ratings.movie_id == movie_id].rating
                explicit_vec.append(int(rating))
            else:
                implicit_vec.append(0)
                explicit_vec.append(3)
        implicit_vec = np.array(implicit_vec)
        explicit_vec = np.array(explicit_vec)

        group_to_implicit_vecs[group['name']].append(implicit_vec)
        group_to_explicit_vecs[group['name']].append(explicit_vec)
        group_to_num_ratings[group['name']] += len(user_movie_set)

group_to_type_to_centroid = defaultdict(dict)
for group_to_vecs, type_ in [
    (group_to_implicit_vecs, 'implicit',),
    (group_to_explicit_vecs, 'explicit',),
]:
    for group, vecs in group_to_vecs.items():
        group_to_type_to_centroid[group][type_] = np.mean(vecs, axis=0)

group_to_group_to_vectype_to_distancetype_to_ = defaultdict(
    lambda: defaultdict(
        lambda: defaultdict(dict)
    )
)
"""
{
    comedy:
        western:
            explicit:
                cosine
                    0.5
                euclidean
                    0.4
            implicit
                cosine
                    0.3
                euclidean
                    0.2
        drama
        ...
        ...
    western:
        ...
        ...
}
"""
for group, type_to_centroid in group_to_type_to_centroid.items():
    for type_, centroid in type_to_centroid.items():
        for group2, type_to_centroid2 in group_to_type_to_centroid.items():
            if group == group2:
                continue
            for type_2, centroid2 in type_to_centroid2.items():
                if type_2 != type_:
                    continue
#                 print('centroid below')
#                 print(centroid)
#                 print('centroid2 below')
#                 print(centroid2)
                group_to_group_to_vectype_to_distancetype_to_[
                    group][group2][type_]['euclidean'] = np.linalg.norm(centroid - centroid2)
                group_to_group_to_vectype_to_distancetype_to_[
                    group][group2][type_]['cosine'] = cosine(centroid, centroid2)
        
def default_to_regular(d):
    if isinstance(d, defaultdict):
        d = {key: default_to_regular(val) for key, val in d.items()}
    return d

group_to_group_to_vectype_to_distancetype_to_ = default_to_regular(group_to_group_to_vectype_to_distancetype_to_)          
pprint(group_to_group_to_vectype_to_distancetype_to_)
import json
with open('some_distances.json', 'w') as f:
    json.dump(group_to_group_to_vectype_to_distancetype_to_, f)
    
with open('group_to_num_ratings.json', 'w') as f:
    json.dump(dict(group_to_num_ratings), f)
# Out:
# Under 18 excluded
# 18-24 excluded
# 25-34 excluded
# 35-44 excluded
# 45-49 excluded
# 50-55 excluded
# 56+ excluded
# usa excluded
# canada excluded
# germany excluded
# united kingdom excluded
# australia excluded
# spain excluded
# france excluded
# portugal excluded
# netherlands excluded
# switzerland excluded
# malaysia excluded
# italy excluded
# austria excluded
# new zealand excluded
# singapore excluded
# finland excluded
# romania excluded
# philippine excluded
# ireland excluded
# japan excluded
# brazil excluded
# sweden excluded
# all
# {'18-24 excluded': {'25-34 excluded': {'explicit': {'cosine': 1.0460477783968969e-07,
#                                                     'euclidean': 0.16244569387765714},
#                                        'implicit': {'cosine': 0.24425011297521537,
#                                                     'euclidean': 0.14565186047194204}},
#                     '35-44 excluded': {'explicit': {'cosine': 1.2583549735545319e-07,
#                                                     'euclidean': 0.17758712425568987},
#                                        'implicit': {'cosine': 0.3555493055728821,
#                                                     'euclidean': 0.17115958760234282}},
#                     '45-49 excluded': {'explicit': {'cosine': 2.5006063719690275e-07,
#                                                     'euclidean': 0.2526815510029293},
#                                        'implicit': {'cosine': 0.46719485746132117,
#                                                     'euclidean': 0.2311825013361415}},
#                     '50-55 excluded': {'explicit': {'cosine': 2.5333910425029416e-07,
#                                                     'euclidean': 0.2534458443492328},
#                                        'implicit': {'cosine': 0.5148374334644662,
#                                                     'euclidean': 0.23131846183540464}},
#                     '56+ excluded': {'explicit': {'cosine': 1.9850383059516474e-07,
#                                                   'euclidean': 0.22191850115442815},
#                                      'implicit': {'cosine': 0.5923891690540064,
#                                                   'euclidean': 0.2110541862172918}},
#                     'Under 18 excluded': {'explicit': {'cosine': 3.14465704809308e-07,
#                                                        'euclidean': 0.27922382375156524},
#                                           'implicit': {'cosine': 0.4922995275190203,
#                                                        'euclidean': 0.22825262693839257}},
#                     'all': {'explicit': {'cosine': 7.781145139329482e-08,
#                                          'euclidean': 0.13917324911676224},
#                             'implicit': {'cosine': 0.24330688738365736,
#                                          'euclidean': 0.13400740501056374}},
#                     'australia excluded': {'explicit': {'cosine': 3.298563262532639e-07,
#                                                         'euclidean': 0.2861078800763047},
#                                            'implicit': {'cosine': 0.6314347144662763,
#                                                         'euclidean': 0.2844082669421209}},
#                     'austria excluded': {'explicit': {'cosine': 1.0791628256567876e-06,
#                                                       'euclidean': 0.5174342092354445},
#                                          'implicit': {'cosine': 0.8032649913277178,
#                                                       'euclidean': 0.4445490496609584}},
#                     'canada excluded': {'explicit': {'cosine': 1.4932995140437555e-07,
#                                                      'euclidean': 0.1924181408287949},
#                                         'implicit': {'cosine': 0.3972937446334882,
#                                                      'euclidean': 0.18460366262774258}},
#                     'finland excluded': {'explicit': {'cosine': 2.3961018527085542e-06,
#                                                       'euclidean': 0.770971769921244},
#                                          'implicit': {'cosine': 0.8221926340317068,
#                                                       'euclidean': 0.6293566837561155}},
#                     'france excluded': {'explicit': {'cosine': 6.54397109278726e-07,
#                                                      'euclidean': 0.4032680562480604},
#                                         'implicit': {'cosine': 0.8535204011313582,
#                                                      'euclidean': 0.4217985382469379}},
#                     'germany excluded': {'explicit': {'cosine': 2.7656521017771496e-07,
#                                                       'euclidean': 0.2626536122005125},
#                                          'implicit': {'cosine': 0.7954326687512956,
#                                                       'euclidean': 0.2673335107294043}},
#                     'ireland excluded': {'explicit': {'cosine': 1.8511126599340955e-06,
#                                                       'euclidean': 0.677892344648171},
#                                          'implicit': {'cosine': 0.8597380988141179,
#                                                       'euclidean': 0.5690613412638947}},
#                     'italy excluded': {'explicit': {'cosine': 1.1053684684236842e-06,
#                                                     'euclidean': 0.523822417581494},
#                                        'implicit': {'cosine': 0.8611763238833152,
#                                                     'euclidean': 0.4384256908625386}},
#                     'japan excluded': {'explicit': {'cosine': 3.096895504595132e-06,
#                                                     'euclidean': 0.8766830206248407},
#                                        'implicit': {'cosine': 0.884033252142046,
#                                                     'euclidean': 0.7857809286441534}},
#                     'malaysia excluded': {'explicit': {'cosine': 1.7405604083586823e-06,
#                                                        'euclidean': 0.6573685091557979},
#                                           'implicit': {'cosine': 0.5473101788698912,
#                                                        'euclidean': 0.5917928146804652}},
#                     'netherlands excluded': {'explicit': {'cosine': 6.368659923872144e-07,
#                                                           'euclidean': 0.3978200626606795},
#                                              'implicit': {'cosine': 0.7863455998430489,
#                                                           'euclidean': 0.422123270234534}},
#                     'new zealand excluded': {'explicit': {'cosine': 1.4951721124534245e-06,
#                                                           'euclidean': 0.6088936534609235},
#                                              'implicit': {'cosine': 0.799478114823505,
#                                                           'euclidean': 0.5949371444384388}},
#                     'philippine excluded': {'explicit': {'cosine': 4.3427747459245936e-06,
#                                                          'euclidean': 1.0377199007131463},
#                                             'implicit': {'cosine': 0.7514233222984723,
#                                                          'euclidean': 0.8354750710802605}},
#                     'portugal excluded': {'explicit': {'cosine': 1.0827431721205372e-06,
#                                                        'euclidean': 0.5188093261374183},
#                                           'implicit': {'cosine': 0.6899595603383137,
#                                                        'euclidean': 0.5551726018368522}},
#                     'romania excluded': {'explicit': {'cosine': 5.4271845292275245e-06,
#                                                       'euclidean': 1.160671055208799},
#                                          'implicit': {'cosine': 0.7783887241533624,
#                                                       'euclidean': 0.7635067701756364}},
#                     'singapore excluded': {'explicit': {'cosine': 1.717262217981741e-06,
#                                                         'euclidean': 0.6529541838950096},
#                                            'implicit': {'cosine': 0.7516093417872179,
#                                                         'euclidean': 0.6138360731286866}},
#                     'spain excluded': {'explicit': {'cosine': 3.871348956963061e-07,
#                                                     'euclidean': 0.31075991502892536},
#                                        'implicit': {'cosine': 0.76681840983521,
#                                                     'euclidean': 0.3336571015775083}},
#                     'switzerland excluded': {'explicit': {'cosine': 6.645500577606711e-07,
#                                                           'euclidean': 0.4064467412292358},
#                                              'implicit': {'cosine': 0.8756297379168211,
#                                                           'euclidean': 0.38786529551972887}},
#                     'united kingdom excluded': {'explicit': {'cosine': 3.213551970082662e-07,
#                                                              'euclidean': 0.28227245497812375},
#                                                 'implicit': {'cosine': 0.6592423816007711,
#                                                              'euclidean': 0.283985120106923}},
#                     'usa excluded': {'explicit': {'cosine': 8.431156162114206e-08,
#                                                   'euclidean': 0.14522966846359864},
#                                      'implicit': {'cosine': 0.265292467412547,
#                                                   'euclidean': 0.144715989000023}}},
#  '25-34 excluded': {'18-24 excluded': {'explicit': {'cosine': 1.0460477783968969e-07,
#                                                     'euclidean': 0.16244569387765714},
#                                        'implicit': {'cosine': 0.24425011297521537,
#                                                     'euclidean': 0.14565186047194204}},
#                     '35-44 excluded': {'explicit': {'cosine': 7.666855517118876e-08,
#                                                     'euclidean': 0.13790216777254435},
#                                        'implicit': {'cosine': 0.16972681188849703,
#                                                     'euclidean': 0.12197777648941188}},
#                     '45-49 excluded': {'explicit': {'cosine': 1.9800112038836915e-07,
#                                                     'euclidean': 0.22263003371098677},
#                                        'implicit': {'cosine': 0.31342048806552547,
#                                                     'euclidean': 0.19420364746084776}},
#                     '50-55 excluded': {'explicit': {'cosine': 2.0002755696246766e-07,
#                                                     'euclidean': 0.22330555381436984},
#                                        'implicit': {'cosine': 0.3574053474700153,
#                                                     'euclidean': 0.1972454528573998}},
#                     '56+ excluded': {'explicit': {'cosine': 1.5634975725209443e-07,
#                                                   'euclidean': 0.19879600547199938},
#                                      'implicit': {'cosine': 0.4377400169625597,
#                                                   'euclidean': 0.18814175229091776}},
#                     'Under 18 excluded': {'explicit': {'cosine': 2.9580366800452396e-07,
#                                                        'euclidean': 0.2718933239762521},
#                                           'implicit': {'cosine': 0.5395489832430576,
#                                                        'euclidean': 0.24294169314383743}},
#                     'all': {'explicit': {'cosine': 3.163030093400465e-08,
#                                          'euclidean': 0.08942604482896375},
#                             'implicit': {'cosine': 0.07030020718489449,
#                                          'euclidean': 0.08198365954788914}},
#                     'australia excluded': {'explicit': {'cosine': 2.980333615454356e-07,
#                                                         'euclidean': 0.2735425754305822},
#                                            'implicit': {'cosine': 0.5490284980349602,
#                                                         'euclidean': 0.2703729251994604}},
#                     'austria excluded': {'explicit': {'cosine': 1.0649067533341494e-06,
#                                                       'euclidean': 0.515079223792867},
#                                          'implicit': {'cosine': 0.8143769897309975,
#                                                       'euclidean': 0.4500220997821016}},
#                     'canada excluded': {'explicit': {'cosine': 1.0172433195787534e-07,
#                                                      'euclidean': 0.15995580260305073},
#                                         'implicit': {'cosine': 0.23320186756213157,
#                                                      'euclidean': 0.1452414447702944}},
#                     'finland excluded': {'explicit': {'cosine': 2.329501740505613e-06,
#                                                       'euclidean': 0.7610900596597757},
#                                          'implicit': {'cosine': 0.7994652330851719,
#                                                       'euclidean': 0.6262180464650251}},
#                     'france excluded': {'explicit': {'cosine': 6.665478727851948e-07,
#                                                      'euclidean': 0.40860928304156785},
#                                         'implicit': {'cosine': 0.8740052192288358,
#                                                      'euclidean': 0.429971573298527}},
#                     'germany excluded': {'explicit': {'cosine': 2.4663739506269877e-07,
#                                                       'euclidean': 0.25081917443728496},
#                                          'implicit': {'cosine': 0.7487805400294972,
#                                                       'euclidean': 0.26612512616205586}},
#                     'ireland excluded': {'explicit': {'cosine': 1.8191831716585227e-06,
#                                                       'euclidean': 0.673209058761503},
#                                          'implicit': {'cosine': 0.8539850878267962,
#                                                       'euclidean': 0.5704749531342929}},
#                     'italy excluded': {'explicit': {'cosine': 1.0716384611919594e-06,
#                                                     'euclidean': 0.5170389508549503},
#                                        'implicit': {'cosine': 0.8324288313782743,
#                                                     'euclidean': 0.4365198604395695}},
#                     'japan excluded': {'explicit': {'cosine': 3.0596021226569903e-06,
#                                                     'euclidean': 0.8724164488119073},
#                                        'implicit': {'cosine': 0.8688815958478986,
#                                                     'euclidean': 0.7842777226686767}},
#                     'malaysia excluded': {'explicit': {'cosine': 1.7161763405937336e-06,
#                                                        'euclidean': 0.6523159610638256},
#                                           'implicit': {'cosine': 0.5335391305294565,
#                                                        'euclidean': 0.5867782481988328}},
#                     'netherlands excluded': {'explicit': {'cosine': 5.940838777585e-07,
#                                                           'euclidean': 0.38595166282567805},
#                                              'implicit': {'cosine': 0.7104218085090199,
#                                                           'euclidean': 0.40919137588728277}},
#                     'new zealand excluded': {'explicit': {'cosine': 1.4729470447782944e-06,
#                                                           'euclidean': 0.6044296350630146},
#                                              'implicit': {'cosine': 0.757107476918478,
#                                                           'euclidean': 0.5874353621820989}},
#                     'philippine excluded': {'explicit': {'cosine': 4.329652170786957e-06,
#                                                          'euclidean': 1.0360967402334624},
#                                             'implicit': {'cosine': 0.7750402887671125,
#                                                          'euclidean': 0.8405759988784572}},
#                     'portugal excluded': {'explicit': {'cosine': 1.02651685640609e-06,
#                                                        'euclidean': 0.5045247098555231},
#                                           'implicit': {'cosine': 0.6176587561161295,
#                                                        'euclidean': 0.5392734831669902}},
#                     'romania excluded': {'explicit': {'cosine': 5.537474069838844e-06,
#                                                       'euclidean': 1.1718983056425454},
#                                          'implicit': {'cosine': 0.782184582356877,
#                                                       'euclidean': 0.7648584384315839}},
#                     'singapore excluded': {'explicit': {'cosine': 1.697216732488016e-06,
#                                                         'euclidean': 0.6503521824206074},
#                                            'implicit': {'cosine': 0.7828724235147468,
#                                                         'euclidean': 0.621620925760407}},
#                     'spain excluded': {'explicit': {'cosine': 3.7438275635182094e-07,
#                                                     'euclidean': 0.3080925102450852},
#                                        'implicit': {'cosine': 0.7699804934871598,
#                                                     'euclidean': 0.3389050717554}},
#                     'switzerland excluded': {'explicit': {'cosine': 6.173909595785787e-07,
#                                                           'euclidean': 0.39356232145704545},
#                                              'implicit': {'cosine': 0.839047790520606,
#                                                           'euclidean': 0.3855400233064171}},
#                     'united kingdom excluded': {'explicit': {'cosine': 2.897708446525371e-07,
#                                                              'euclidean': 0.26918439484058887},
#                                                 'implicit': {'cosine': 0.6053943645071314,
#                                                              'euclidean': 0.27714672968186305}},
#                     'usa excluded': {'explicit': {'cosine': 3.350348565245298e-08,
#                                                   'euclidean': 0.09145327659637532},
#                                      'implicit': {'cosine': 0.09145758841087925,
#                                                   'euclidean': 0.08924589172881779}}},
#  '35-44 excluded': {'18-24 excluded': {'explicit': {'cosine': 1.2583549735545319e-07,
#                                                     'euclidean': 0.17758712425568987},
#                                        'implicit': {'cosine': 0.3555493055728821,
#                                                     'euclidean': 0.17115958760234282}},
#                     '25-34 excluded': {'explicit': {'cosine': 7.666855517118876e-08,
#                                                     'euclidean': 0.13790216777254435},
#                                        'implicit': {'cosine': 0.16972681188849703,
#                                                     'euclidean': 0.12197777648941188}},
#                     '45-49 excluded': {'explicit': {'cosine': 1.824472337652594e-07,
#                                                     'euclidean': 0.21410383151910534},
#                                        'implicit': {'cosine': 0.2658277647660088,
#                                                     'euclidean': 0.17905906073485664}},
#                     '50-55 excluded': {'explicit': {'cosine': 1.7886963865620942e-07,
#                                                     'euclidean': 0.21147550327242196},
#                                        'implicit': {'cosine': 0.2940065908388739,
#                                                     'euclidean': 0.17760664406836846}},
#                     '56+ excluded': {'explicit': {'cosine': 1.2809293192805882e-07,
#                                                   'euclidean': 0.17989938712387862},
#                                      'implicit': {'cosine': 0.33679996524563716,
#                                                   'euclidean': 0.160478268990503}},
#                     'Under 18 excluded': {'explicit': {'cosine': 3.39041201780077e-07,
#                                                        'euclidean': 0.29071086193157425},
#                                           'implicit': {'cosine': 0.6274116853005764,
#                                                        'euclidean': 0.2572377305657525}},
#                     'all': {'explicit': {'cosine': 3.167722806285411e-08,
#                                          'euclidean': 0.08913528982239292},
#                             'implicit': {'cosine': 0.07018694172531459,
#                                          'euclidean': 0.07634704171399506}},
#                     'australia excluded': {'explicit': {'cosine': 2.860432857243467e-07,
#                                                         'euclidean': 0.26773878950670427},
#                                            'implicit': {'cosine': 0.5659082766866186,
#                                                         'euclidean': 0.27120805282674154}},
#                     'austria excluded': {'explicit': {'cosine': 1.087026815227432e-06,
#                                                       'euclidean': 0.520180856116396},
#                                          'implicit': {'cosine': 0.8506577484689474,
#                                                       'euclidean': 0.4544463380810108}},
#                     'canada excluded': {'explicit': {'cosine': 9.981112725210295e-08,
#                                                      'euclidean': 0.15814326973960963},
#                                         'implicit': {'cosine': 0.24937653122598702,
#                                                      'euclidean': 0.14693750148010037}},
#                     'finland excluded': {'explicit': {'cosine': 2.3656917282899315e-06,
#                                                       'euclidean': 0.7668059090907605},
#                                          'implicit': {'cosine': 0.8327860077621361,
#                                                       'euclidean': 0.6317937343059938}},
#                     'france excluded': {'explicit': {'cosine': 6.683743315472057e-07,
#                                                      'euclidean': 0.40887909330484146},
#                                         'implicit': {'cosine': 0.9034305881803623,
#                                                      'euclidean': 0.4319918036762645}},
#                     'germany excluded': {'explicit': {'cosine': 2.4019483157999844e-07,
#                                                       'euclidean': 0.24714063673520184},
#                                          'implicit': {'cosine': 0.772181596246189,
#                                                       'euclidean': 0.2645006421946475}},
#                     'ireland excluded': {'explicit': {'cosine': 1.832126752643326e-06,
#                                                       'euclidean': 0.675389801260536},
#                                          'implicit': {'cosine': 0.8542484134562889,
#                                                       'euclidean': 0.568366372907566}},
#                     'italy excluded': {'explicit': {'cosine': 1.0592318124835742e-06,
#                                                     'euclidean': 0.5138332248744019},
#                                        'implicit': {'cosine': 0.8462179411663596,
#                                                     'euclidean': 0.4361298985693108}},
#                     'japan excluded': {'explicit': {'cosine': 3.043051526541163e-06,
#                                                     'euclidean': 0.8698928417396171},
#                                        'implicit': {'cosine': 0.8766824256500111,
#                                                     'euclidean': 0.7845535244395152}},
#                     'malaysia excluded': {'explicit': {'cosine': 1.8359262302647394e-06,
#                                                        'euclidean': 0.6747077227766916},
#                                           'implicit': {'cosine': 0.6308264583610621,
#                                                        'euclidean': 0.6100666763131127}},
#                     'netherlands excluded': {'explicit': {'cosine': 5.819710749976892e-07,
#                                                           'euclidean': 0.3817414130379226},
#                                              'implicit': {'cosine': 0.7022851811943268,
#                                                           'euclidean': 0.40539409501030677}},
#                     'new zealand excluded': {'explicit': {'cosine': 1.4524306741758863e-06,
#                                                           'euclidean': 0.6001523421667186},
#                                              'implicit': {'cosine': 0.7659812862376901,
#                                                           'euclidean': 0.588252873590032}},
#                     'philippine excluded': {'explicit': {'cosine': 4.441165027402327e-06,
#                                                          'euclidean': 1.0493358714432477},
#                                             'implicit': {'cosine': 0.8008757513082747,
#                                                          'euclidean': 0.8457946229603197}},
#                     'portugal excluded': {'explicit': {'cosine': 1.089720749747336e-06,
#                                                        'euclidean': 0.5198598487678567},
#                                           'implicit': {'cosine': 0.6997729334131865,
#                                                        'euclidean': 0.5573458664896868}},
#                     'romania excluded': {'explicit': {'cosine': 5.607907357707553e-06,
#                                                       'euclidean': 1.1793694987887025},
#                                          'implicit': {'cosine': 0.8436133159400812,
#                                                       'euclidean': 0.7770872864210256}},
#                     'singapore excluded': {'explicit': {'cosine': 1.6711413810543974e-06,
#                                                         'euclidean': 0.645156873297439},
#                                            'implicit': {'cosine': 0.785993263074034,
#                                                         'euclidean': 0.62115098632394}},
#                     'spain excluded': {'explicit': {'cosine': 3.6905593325808894e-07,
#                                                     'euclidean': 0.30552103536573494},
#                                        'implicit': {'cosine': 0.7973156867153625,
#                                                     'euclidean': 0.3402215158218837}},
#                     'switzerland excluded': {'explicit': {'cosine': 6.110429495720382e-07,
#                                                           'euclidean': 0.39125121264333124},
#                                              'implicit': {'cosine': 0.8490372829400263,
#                                                           'euclidean': 0.38361465659811417}},
#                     'united kingdom excluded': {'explicit': {'cosine': 2.8519634753809697e-07,
#                                                              'euclidean': 0.2668148799395123},
#                                                 'implicit': {'cosine': 0.6291862523496181,
#                                                              'euclidean': 0.27860207673380427}},
#                     'usa excluded': {'explicit': {'cosine': 3.3205764915500424e-08,
#                                                   'euclidean': 0.09085442880705176},
#                                      'implicit': {'cosine': 0.07843506436943859,
#                                                   'euclidean': 0.07946713128456287}}},
#  '45-49 excluded': {'18-24 excluded': {'explicit': {'cosine': 2.5006063719690275e-07,
#                                                     'euclidean': 0.2526815510029293},
#                                        'implicit': {'cosine': 0.46719485746132117,
#                                                     'euclidean': 0.2311825013361415}},
#                     '25-34 excluded': {'explicit': {'cosine': 1.9800112038836915e-07,
#                                                     'euclidean': 0.22263003371098677},
#                                        'implicit': {'cosine': 0.31342048806552547,
#                                                     'euclidean': 0.19420364746084776}},
#                     '35-44 excluded': {'explicit': {'cosine': 1.824472337652594e-07,
#                                                     'euclidean': 0.21410383151910534},
#                                        'implicit': {'cosine': 0.2658277647660088,
#                                                     'euclidean': 0.17905906073485664}},
#                     '50-55 excluded': {'explicit': {'cosine': 2.830318177604596e-07,
#                                                     'euclidean': 0.2649696570310566},
#                                        'implicit': {'cosine': 0.36116710920852846,
#                                                     'euclidean': 0.2174617998915091}},
#                     '56+ excluded': {'explicit': {'cosine': 2.363893161216879e-07,
#                                                   'euclidean': 0.24704175948975468},
#                                      'implicit': {'cosine': 0.3832591859829012,
#                                                   'euclidean': 0.2084479330371444}},
#                     'Under 18 excluded': {'explicit': {'cosine': 4.565478420870406e-07,
#                                                        'euclidean': 0.3395695810704316},
#                                           'implicit': {'cosine': 0.6906922793983725,
#                                                        'euclidean': 0.30194491751916713}},
#                     'all': {'explicit': {'cosine': 1.4474350462645447e-07,
#                                          'euclidean': 0.1924896437309797},
#                             'implicit': {'cosine': 0.1968495756459554,
#                                          'euclidean': 0.16090214527475802}},
#                     'australia excluded': {'explicit': {'cosine': 4.2274120848340146e-07,
#                                                         'euclidean': 0.3279428241208314},
#                                            'implicit': {'cosine': 0.6473072607415582,
#                                                         'euclidean': 0.3143010896882841}},
#                     'austria excluded': {'explicit': {'cosine': 1.2065882609713086e-06,
#                                                       'euclidean': 0.5499863348911262},
#                                          'implicit': {'cosine': 0.887875822661913,
#                                                       'euclidean': 0.48483939273060683}},
#                     'canada excluded': {'explicit': {'cosine': 2.2209678951501388e-07,
#                                                      'euclidean': 0.23818312763040675},
#                                         'implicit': {'cosine': 0.35434449502261833,
#                                                      'euclidean': 0.20531879425622407}},
#                     'finland excluded': {'explicit': {'cosine': 2.4644244589477893e-06,
#                                                       'euclidean': 0.7842398920938919},
#                                          'implicit': {'cosine': 0.8619099627331653,
#                                                       'euclidean': 0.6511792717316537}},
#                     'france excluded': {'explicit': {'cosine': 8.006968980067697e-07,
#                                                      'euclidean': 0.44999706792273286},
#                                         'implicit': {'cosine': 0.9256926259738855,
#                                                      'euclidean': 0.46308834873259414}},
#                     'germany excluded': {'explicit': {'cosine': 3.748336940834207e-07,
#                                                       'euclidean': 0.31142946628030965},
#                                          'implicit': {'cosine': 0.8266392567946927,
#                                                       'euclidean': 0.3131314787272055}},
#                     'ireland excluded': {'explicit': {'cosine': 1.938238919141355e-06,
#                                                       'euclidean': 0.6966139463160878},
#                                          'implicit': {'cosine': 0.8762633938900629,
#                                                       'euclidean': 0.5895473858505157}},
#                     'italy excluded': {'explicit': {'cosine': 1.1849996062185397e-06,
#                                                     'euclidean': 0.545607361838716},
#                                        'implicit': {'cosine': 0.8729592204852279,
#                                                     'euclidean': 0.4649660802401408}},
#                     'japan excluded': {'explicit': {'cosine': 3.1850627707497026e-06,
#                                                     'euclidean': 0.8916031152179502},
#                                        'implicit': {'cosine': 0.9088926370888141,
#                                                     'euclidean': 0.8031632757044432}},
#                     'malaysia excluded': {'explicit': {'cosine': 1.925787656009703e-06,
#                                                        'euclidean': 0.691260219439098},
#                                           'implicit': {'cosine': 0.6833646248311345,
#                                                        'euclidean': 0.6239555700817275}},
#                     'netherlands excluded': {'explicit': {'cosine': 6.974958065564252e-07,
#                                                           'euclidean': 0.4205385405073129},
#                                              'implicit': {'cosine': 0.7498121485881346,
#                                                           'euclidean': 0.4333341775340182}},
#                     'new zealand excluded': {'explicit': {'cosine': 1.5801829559292102e-06,
#                                                           'euclidean': 0.6268575352501855},
#                                              'implicit': {'cosine': 0.8061441191838534,
#                                                           'euclidean': 0.6080954889339252}},
#                     'philippine excluded': {'explicit': {'cosine': 4.5561117169024e-06,
#                                                          'euclidean': 1.0632325304918604},
#                                             'implicit': {'cosine': 0.8354156840937456,
#                                                          'euclidean': 0.8592993259440216}},
#                     'portugal excluded': {'explicit': {'cosine': 1.2231746903124119e-06,
#                                                        'euclidean': 0.5509540217899571},
#                                           'implicit': {'cosine': 0.760372322557807,
#                                                        'euclidean': 0.5798145626444274}},
#                     'romania excluded': {'explicit': {'cosine': 5.7133115201057905e-06,
#                                                       'euclidean': 1.190253823698793},
#                                          'implicit': {'cosine': 0.8655832774827148,
#                                                       'euclidean': 0.7912771625319922}},
#                     'singapore excluded': {'explicit': {'cosine': 1.7909434599783225e-06,
#                                                         'euclidean': 0.6698726519622017},
#                                            'implicit': {'cosine': 0.8328339793349353,
#                                                         'euclidean': 0.6427199254332333}},
#                     'spain excluded': {'explicit': {'cosine': 4.939662719971594e-07,
#                                                     'euclidean': 0.3564187523604774},
#                                        'implicit': {'cosine': 0.8423649812020619,
#                                                     'euclidean': 0.3786460307409695}},
#                     'switzerland excluded': {'explicit': {'cosine': 7.591410098317652e-07,
#                                                           'euclidean': 0.43860077476784554},
#                                              'implicit': {'cosine': 0.8976745276532259,
#                                                           'euclidean': 0.42146938465971145}},
#                     'united kingdom excluded': {'explicit': {'cosine': 4.217453154486961e-07,
#                                                              'euclidean': 0.3267033474460361},
#                                                 'implicit': {'cosine': 0.7152582038407138,
#                                                              'euclidean': 0.3251348213449031}},
#                     'usa excluded': {'explicit': {'cosine': 1.4062828701533192e-07,
#                                                   'euclidean': 0.18900441246755806},
#                                      'implicit': {'cosine': 0.19699740625578444,
#                                                   'euclidean': 0.15776117383291555}}},
#  '50-55 excluded': {'18-24 excluded': {'explicit': {'cosine': 2.5333910425029416e-07,
#                                                     'euclidean': 0.2534458443492328},
#                                        'implicit': {'cosine': 0.5148374334644662,
#                                                     'euclidean': 0.23131846183540464}},
#                     '25-34 excluded': {'explicit': {'cosine': 2.0002755696246766e-07,
#                                                     'euclidean': 0.22330555381436984},
#                                        'implicit': {'cosine': 0.3574053474700153,
#                                                     'euclidean': 0.1972454528573998}},
#                     '35-44 excluded': {'explicit': {'cosine': 1.7886963865620942e-07,
#                                                     'euclidean': 0.21147550327242196},
#                                        'implicit': {'cosine': 0.2940065908388739,
#                                                     'euclidean': 0.17760664406836846}},
#                     '45-49 excluded': {'explicit': {'cosine': 2.830318177604596e-07,
#                                                     'euclidean': 0.2649696570310566},
#                                        'implicit': {'cosine': 0.36116710920852846,
#                                                     'euclidean': 0.2174617998915091}},
#                     '56+ excluded': {'explicit': {'cosine': 2.0717374549228396e-07,
#                                                   'euclidean': 0.23085703627103574},
#                                      'implicit': {'cosine': 0.36659764462457645,
#                                                   'euclidean': 0.19347104095259227}},
#                     'Under 18 excluded': {'explicit': {'cosine': 4.6924191332564646e-07,
#                                                        'euclidean': 0.3435063477594566},
#                                           'implicit': {'cosine': 0.7138029797382821,
#                                                        'euclidean': 0.2972722287547873}},
#                     'all': {'explicit': {'cosine': 1.3843542079339244e-07,
#                                          'euclidean': 0.1874996678169793},
#                             'implicit': {'cosine': 0.22839784108998962,
#                                          'euclidean': 0.15808561671287824}},
#                     'australia excluded': {'explicit': {'cosine': 3.9889901326528587e-07,
#                                                         'euclidean': 0.3179790841139108},
#                                            'implicit': {'cosine': 0.6408164751957277,
#                                                         'euclidean': 0.30490846091376345}},
#                     'austria excluded': {'explicit': {'cosine': 1.1967464684792262e-06,
#                                                       'euclidean': 0.5472289616823363},
#                                          'implicit': {'cosine': 0.8959185771070152,
#                                                       'euclidean': 0.47984255135633186}},
#                     'canada excluded': {'explicit': {'cosine': 2.061706447786804e-07,
#                                                      'euclidean': 0.22886628822027671},
#                                         'implicit': {'cosine': 0.37247835509149596,
#                                                      'euclidean': 0.2007006359286237}},
#                     'finland excluded': {'explicit': {'cosine': 2.4672132624692367e-06,
#                                                       'euclidean': 0.7842653266436863},
#                                          'implicit': {'cosine': 0.8688442579068034,
#                                                       'euclidean': 0.6487403239133557}},
#                     'france excluded': {'explicit': {'cosine': 7.760733895523231e-07,
#                                                      'euclidean': 0.44243933954748327},
#                                         'implicit': {'cosine': 0.9271382494966733,
#                                                      'euclidean': 0.4555899442465168}},
#                     'germany excluded': {'explicit': {'cosine': 3.600548856841357e-07,
#                                                       'euclidean': 0.3044336168571323},
#                                          'implicit': {'cosine': 0.8375340773661277,
#                                                       'euclidean': 0.3038754016140331}},
#                     'ireland excluded': {'explicit': {'cosine': 1.9492998801773354e-06,
#                                                       'euclidean': 0.6980745746533562},
#                                          'implicit': {'cosine': 0.8981854511128267,
#                                                       'euclidean': 0.589691818365874}},
#                     'italy excluded': {'explicit': {'cosine': 1.1791831581176027e-06,
#                                                     'euclidean': 0.5437013047420209},
#                                        'implicit': {'cosine': 0.8891004826645044,
#                                                     'euclidean': 0.46162668987430555}},
#                     'japan excluded': {'explicit': {'cosine': 3.160181903494319e-06,
#                                                     'euclidean': 0.8877132476423394},
#                                        'implicit': {'cosine': 0.930952457033959,
#                                                     'euclidean': 0.8048381984005518}},
#                     'malaysia excluded': {'explicit': {'cosine': 1.957773421379372e-06,
#                                                        'euclidean': 0.696849446111878},
#                                           'implicit': {'cosine': 0.7136797761658182,
#                                                        'euclidean': 0.630573724675785}},
#                     'netherlands excluded': {'explicit': {'cosine': 6.95848134113497e-07,
#                                                           'euclidean': 0.41929622363239544},
#                                              'implicit': {'cosine': 0.7575120216215323,
#                                                           'euclidean': 0.4295983955841349}},
#                     'new zealand excluded': {'explicit': {'cosine': 1.5872386242010705e-06,
#                                                           'euclidean': 0.6279836541349344},
#                                              'implicit': {'cosine': 0.8256145931530396,
#                                                           'euclidean': 0.6092301529075917}},
#                     'philippine excluded': {'explicit': {'cosine': 4.603595550656259e-06,
#                                                          'euclidean': 1.0686210302210433},
#                                             'implicit': {'cosine': 0.8527149872884968,
#                                                          'euclidean': 0.8614924161167532}},
#                     'portugal excluded': {'explicit': {'cosine': 1.2316287311131546e-06,
#                                                        'euclidean': 0.5527208979955857},
#                                           'implicit': {'cosine': 0.7716804332994686,
#                                                        'euclidean': 0.5794608301007836}},
#                     'romania excluded': {'explicit': {'cosine': 5.791900183016452e-06,
#                                                       'euclidean': 1.198400164579133},
#                                          'implicit': {'cosine': 0.8994681274986206,
#                                                       'euclidean': 0.796528739259087}},
#                     'singapore excluded': {'explicit': {'cosine': 1.7555137953317868e-06,
#                                                         'euclidean': 0.6627543005873524},
#                                            'implicit': {'cosine': 0.8219804712141003,
#                                                         'euclidean': 0.6363439120501565}},
#                     'spain excluded': {'explicit': {'cosine': 4.877775465761403e-07,
#                                                     'euclidean': 0.3532902495214852},
#                                        'implicit': {'cosine': 0.8650793648732278,
#                                                     'euclidean': 0.3746971559630991}},
#                     'switzerland excluded': {'explicit': {'cosine': 7.246699595953032e-07,
#                                                           'euclidean': 0.4279837477514823},
#                                              'implicit': {'cosine': 0.9001389119517313,
#                                                           'euclidean': 0.41365585210247746}},
#                     'united kingdom excluded': {'explicit': {'cosine': 4.0416158864076124e-07,
#                                                              'euclidean': 0.31923522755958367},
#                                                 'implicit': {'cosine': 0.7274574460135221,
#                                                              'euclidean': 0.31908482187694953}},
#                     'usa excluded': {'explicit': {'cosine': 1.3825363465169715e-07,
#                                                   'euclidean': 0.18669030120585747},
#                                      'implicit': {'cosine': 0.2293031793085092,
#                                                   'euclidean': 0.15766990109615928}}},
#  '56+ excluded': {'18-24 excluded': {'explicit': {'cosine': 1.9850383059516474e-07,
#                                                   'euclidean': 0.22191850115442815},
#                                      'implicit': {'cosine': 0.5923891690540064,
#                                                   'euclidean': 0.2110541862172918}},
#                   '25-34 excluded': {'explicit': {'cosine': 1.5634975725209443e-07,
#                                                   'euclidean': 0.19879600547199938},
# ...
#                                                   'implicit': {'cosine': 0.8408492829584424,
#                                                                'euclidean': 0.4806011716399262}},
#                              'canada excluded': {'explicit': {'cosine': 3.101668479832398e-07,
#                                                               'euclidean': 0.27735383817922804},
#                                                  'implicit': {'cosine': 0.695645162056413,
#                                                               'euclidean': 0.2951631606162754}},
#                              'finland excluded': {'explicit': {'cosine': 2.4972414297552703e-06,
#                                                                'euclidean': 0.7869736623720094},
#                                                   'implicit': {'cosine': 0.8616820788682833,
#                                                                'euclidean': 0.6558255153813071}},
#                              'france excluded': {'explicit': {'cosine': 7.964457011677695e-07,
#                                                               'euclidean': 0.444639203046169},
#                                                  'implicit': {'cosine': 0.898747494044902,
#                                                               'euclidean': 0.4652724598479449}},
#                              'germany excluded': {'explicit': {'cosine': 4.042564950568206e-07,
#                                                                'euclidean': 0.3170231043883599},
#                                                   'implicit': {'cosine': 0.8833991259741758,
#                                                                'euclidean': 0.33596821983920494}},
#                              'ireland excluded': {'explicit': {'cosine': 1.9381826004138958e-06,
#                                                                'euclidean': 0.6935010064472593},
#                                                   'implicit': {'cosine': 0.8344523178631081,
#                                                                'euclidean': 0.5841104336156699}},
#                              'italy excluded': {'explicit': {'cosine': 1.2227418151322667e-06,
#                                                              'euclidean': 0.5507776514311024},
#                                                 'implicit': {'cosine': 0.9022144121788856,
#                                                              'euclidean': 0.4799399920937943}},
#                              'japan excluded': {'explicit': {'cosine': 3.141068708578665e-06,
#                                                              'euclidean': 0.8827867467682128},
#                                                 'implicit': {'cosine': 0.8746562517693157,
#                                                              'euclidean': 0.7979651837235053}},
#                              'malaysia excluded': {'explicit': {'cosine': 2.0339657801349276e-06,
#                                                                 'euclidean': 0.7106757429575318},
#                                                    'implicit': {'cosine': 0.7857780224394413,
#                                                                 'euclidean': 0.655006777692225}},
#                              'netherlands excluded': {'explicit': {'cosine': 7.685217595643223e-07,
#                                                                    'euclidean': 0.4367686991751375},
#                                                       'implicit': {'cosine': 0.7970135801547286,
#                                                                    'euclidean': 0.45207916721553154}},
#                              'new zealand excluded': {'explicit': {'cosine': 1.547246165189975e-06,
#                                                                    'euclidean': 0.6194632528193089},
#                                                       'implicit': {'cosine': 0.7658867822874122,
#                                                                    'euclidean': 0.6011640850299718}},
#                              'philippine excluded': {'explicit': {'cosine': 4.708368034678223e-06,
#                                                                   'euclidean': 1.0805583614500904},
#                                                      'implicit': {'cosine': 0.9314637995728916,
#                                                                   'euclidean': 0.8883185655430859}},
#                              'portugal excluded': {'explicit': {'cosine': 1.2555563140281834e-06,
#                                                                 'euclidean': 0.5587580638010633},
#                                                    'implicit': {'cosine': 0.8030661390578222,
#                                                                 'euclidean': 0.5954300031411228}},
#                              'romania excluded': {'explicit': {'cosine': 5.80924400195304e-06,
#                                                                'euclidean': 1.2009020596361586},
#                                                   'implicit': {'cosine': 0.8952007357256587,
#                                                                'euclidean': 0.8029043229328461}},
#                              'singapore excluded': {'explicit': {'cosine': 1.7680793150676166e-06,
#                                                                  'euclidean': 0.6623970818718878},
#                                                     'implicit': {'cosine': 0.8392787000594406,
#                                                                  'euclidean': 0.6487788121120881}},
#                              'spain excluded': {'explicit': {'cosine': 5.442661437093932e-07,
#                                                              'euclidean': 0.3679097622339619},
#                                                 'implicit': {'cosine': 0.888991473448372,
#                                                              'euclidean': 0.398809649877387}},
#                              'switzerland excluded': {'explicit': {'cosine': 7.479830116396968e-07,
#                                                                    'euclidean': 0.43097292773007695},
#                                                       'implicit': {'cosine': 0.8706986013713287,
#                                                                    'euclidean': 0.42437525548722205}},
#                              'usa excluded': {'explicit': {'cosine': 2.8594327594611e-07,
#                                                            'euclidean': 0.2668147997921757},
#                                               'implicit': {'cosine': 0.6846481476244729,
#                                                            'euclidean': 0.2862726881632423}}},
#  'usa excluded': {'18-24 excluded': {'explicit': {'cosine': 8.431156162114206e-08,
#                                                   'euclidean': 0.14522966846359864},
#                                      'implicit': {'cosine': 0.265292467412547,
#                                                   'euclidean': 0.144715989000023}},
#                   '25-34 excluded': {'explicit': {'cosine': 3.350348565245298e-08,
#                                                   'euclidean': 0.09145327659637532},
#                                      'implicit': {'cosine': 0.09145758841087925,
#                                                   'euclidean': 0.08924589172881779}},
#                   '35-44 excluded': {'explicit': {'cosine': 3.3205764915500424e-08,
#                                                   'euclidean': 0.09085442880705176},
#                                      'implicit': {'cosine': 0.07843506436943859,
#                                                   'euclidean': 0.07946713128456287}},
#                   '45-49 excluded': {'explicit': {'cosine': 1.4062828701533192e-07,
#                                                   'euclidean': 0.18900441246755806},
#                                      'implicit': {'cosine': 0.19699740625578444,
#                                                   'euclidean': 0.15776117383291555}},
#                   '50-55 excluded': {'explicit': {'cosine': 1.3825363465169715e-07,
#                                                   'euclidean': 0.18669030120585747},
#                                      'implicit': {'cosine': 0.2293031793085092,
#                                                   'euclidean': 0.15766990109615928}},
#                   '56+ excluded': {'explicit': {'cosine': 9.36269762830122e-08,
#                                                 'euclidean': 0.1536558099061444},
#                                    'implicit': {'cosine': 0.27450232712177935,
#                                                 'euclidean': 0.14100445137892142}},
#                   'Under 18 excluded': {'explicit': {'cosine': 2.762524043964376e-07,
#                                                      'euclidean': 0.26223455801524626},
#                                         'implicit': {'cosine': 0.5357530066146654,
#                                                      'euclidean': 0.23520315787212218}},
#                   'all': {'explicit': {'cosine': 4.828841326798283e-09,
#                                        'euclidean': 0.03494389718382054},
#                           'implicit': {'cosine': 0.013189382820892326,
#                                        'euclidean': 0.03574681073873427}},
#                   'australia excluded': {'explicit': {'cosine': 2.832273139352637e-07,
#                                                       'euclidean': 0.26598340333670983},
#                                          'implicit': {'cosine': 0.5898597068913641,
#                                                       'euclidean': 0.2736881667418826}},
#                   'austria excluded': {'explicit': {'cosine': 1.0671060644007468e-06,
#                                                     'euclidean': 0.515128018546776},
#                                        'implicit': {'cosine': 0.8664656591592497,
#                                                     'euclidean': 0.4547608258240801}},
#                   'canada excluded': {'explicit': {'cosine': 9.218231800112164e-08,
#                                                    'euclidean': 0.15161622142867895},
#                                       'implicit': {'cosine': 0.2421619710306644,
#                                                    'euclidean': 0.14236157227406734}},
#                   'finland excluded': {'explicit': {'cosine': 2.347235183330909e-06,
#                                                     'euclidean': 0.7635865036073287},
#                                        'implicit': {'cosine': 0.8303761862574788,
#                                                     'euclidean': 0.6299886198376142}},
#                   'france excluded': {'explicit': {'cosine': 6.546351983827137e-07,
#                                                    'euclidean': 0.4042706581500357},
#                                       'implicit': {'cosine': 0.9300049373398305,
#                                                    'euclidean': 0.4334519387013382}},
#                   'germany excluded': {'explicit': {'cosine': 2.3253458558691875e-07,
#                                                     'euclidean': 0.24255768570524297},
#                                        'implicit': {'cosine': 0.8223123448946255,
#                                                     'euclidean': 0.2675869250737278}},
#                   'ireland excluded': {'explicit': {'cosine': 1.7971646467662694e-06,
#                                                     'euclidean': 0.6686443528166947},
#                                        'implicit': {'cosine': 0.8623368208049624,
#                                                     'euclidean': 0.5680609335240395}},
#                   'italy excluded': {'explicit': {'cosine': 1.0492543149887013e-06,
#                                                   'euclidean': 0.5110919381687706},
#                                      'implicit': {'cosine': 0.8513449352871512,
#                                                   'euclidean': 0.43429768094662435}},
#                   'japan excluded': {'explicit': {'cosine': 3.036071777318128e-06,
#                                                   'euclidean': 0.8686435655349867},
#                                      'implicit': {'cosine': 0.8863567926475688,
#                                                   'euclidean': 0.7852564505457056}},
#                   'malaysia excluded': {'explicit': {'cosine': 1.7843153011787294e-06,
#                                                      'euclidean': 0.665213203762617},
#                                         'implicit': {'cosine': 0.59636057300099,
#                                                      'euclidean': 0.6034428323047456}},
#                   'netherlands excluded': {'explicit': {'cosine': 5.707788272024672e-07,
#                                                         'euclidean': 0.3776442957860176},
#                                            'implicit': {'cosine': 0.7214718139276346,
#                                                         'euclidean': 0.4075541222025496}},
#                   'new zealand excluded': {'explicit': {'cosine': 1.4552053411165389e-06,
#                                                         'euclidean': 0.6006657639608854},
#                                            'implicit': {'cosine': 0.7809252950174664,
#                                                         'euclidean': 0.5903312396801469}},
#                   'philippine excluded': {'explicit': {'cosine': 4.371782266310298e-06,
#                                                        'euclidean': 1.041094365400827},
#                                           'implicit': {'cosine': 0.7723062490810775,
#                                                        'euclidean': 0.8398011800594221}},
#                   'portugal excluded': {'explicit': {'cosine': 1.0729088671945775e-06,
#                                                      'euclidean': 0.5159298593237499},
#                                         'implicit': {'cosine': 0.6951446799011372,
#                                                      'euclidean': 0.5560090651898508}},
#                   'romania excluded': {'explicit': {'cosine': 5.5657049179425044e-06,
#                                                     'euclidean': 1.1750110802180576},
#                                        'implicit': {'cosine': 0.8220945964220738,
#                                                     'euclidean': 0.7719556485505522}},
#                   'singapore excluded': {'explicit': {'cosine': 1.6745161781628326e-06,
#                                                       'euclidean': 0.6454975499508536},
#                                          'implicit': {'cosine': 0.7877726859175129,
#                                                       'euclidean': 0.6205745369985164}},
#                   'spain excluded': {'explicit': {'cosine': 3.598713942398746e-07,
#                                                   'euclidean': 0.30113799951585773},
#                                      'implicit': {'cosine': 0.8309025249388946,
#                                                   'euclidean': 0.3427332257791646}},
#                   'switzerland excluded': {'explicit': {'cosine': 6.062971589226862e-07,
#                                                         'euclidean': 0.3892902147220957},
#                                            'implicit': {'cosine': 0.895588468350566,
#                                                         'euclidean': 0.3886182160692716}},
#                   'united kingdom excluded': {'explicit': {'cosine': 2.8594327594611e-07,
#                                                            'euclidean': 0.2668147997921757},
#                                               'implicit': {'cosine': 0.6846481476244729,
#                                                            'euclidean': 0.2862726881632423}}}}

# %% [markdown]
# # Start here for Dist. vs. Like-User Damage

# %%
import pandas as pd
import json
import seaborn as sns
import matplotlib.pyplot as plt
with open('some_distances.json', 'r') as f:
    group_to_group_to_vectype_to_distancetype_to_ = json.load(f)
    
row_dicts = []
for group, group_to_vectype_to_distancetype_to_ in group_to_group_to_vectype_to_distancetype_to_.items():
    if group == 'all':
        continue
    row_dict = {}
    row_dict['name'] = group
    for group2, vectype_to_distancetype_to_ in group_to_vectype_to_distancetype_to_.items():
        if group2 != 'all':
            continue
        for vectype, distancetype_to_ in vectype_to_distancetype_to_.items():
            for distancetype, val in distancetype_to_.items():
                row_dict['{}_{}'.format(vectype, distancetype)] = val
    row_dicts.append(row_dict)

df = pd.DataFrame(row_dicts)
df.name = [
    x.replace('excluded', '')
    .replace('users from state', '')
    .strip()
    .lower()
    for x in list(df.name)
]

# %%
with open('all_ratios.json', 'r') as f:
    all_ratios = json.load(f)
    
with open('all_diffs.json', 'r') as f:
    all_diffs = json.load(f)
    
with open('group_to_num_ratings.json', 'r') as f:
    group_to_num_ratings = json.load(f)
temp_df = pd.DataFrame.from_dict(group_to_num_ratings, orient='index')
temp_df.index = [
    x.replace('excluded', '')
    .replace('users from state', '')
    .strip()
    .lower()
    for x in list(temp_df.index)
]
print(temp_df)
group_to_num_ratings = temp_df.to_dict()[0]


#print(group_to_num_ratings)    
lb_ratios = all_ratios['lb']
nb_ratios = all_ratios['nb']


row_dicts = []
for key, val in lb_ratios.items():
    row_dict = {
        'name': key,
        'like-boycott-ratio': val,
        'non-boycott-ratio': nb_ratios[key],
        'like-boycott-diff': all_diffs['lb'][key],
        'non-boycott-diff': all_diffs['lb'][key],
        'num_ratings': group_to_num_ratings[key],
    }
    row_dicts.append(row_dict)
ratios_df = pd.DataFrame(row_dicts)

df = df.merge(right=ratios_df, on='name', how='inner')
print(df.head())
# Out:
#                      0
# under 18          2538
# 18-24             8955
# 25-34            36884
# 35-44            26914
# 45-49             9316
# 50-55             9153
# 56+               7177
# usa             106953
# canada           13608
# germany           2509
# united kingdom    3383
# australia         1869
# spain             1374
# france             977
# portugal          1401
# netherlands        592
# switzerland        389
# malaysia           958
# italy              256
# austria            292
# new zealand        489
# singapore          238
# finland            156
# romania            165
# philippine         211
# ireland             96
# japan              122
# all             145888
#        name  implicit_euclidean  implicit_cosine  explicit_euclidean  \
# 0  under 18            0.229271         0.534845            0.261837
# 1     18-24            0.134007         0.243307            0.139173
# 2     25-34            0.081984         0.070300            0.089426
# 3     35-44            0.076347         0.070187            0.089135
# 4     45-49            0.160902         0.196850            0.192490
#
#    explicit_cosine  like-boycott-ratio  non-boycott-ratio  like-boycott-diff  \
# 0     2.759794e-07           23.759435           0.945829         -37.509425
# 1     7.781145e-08            7.369377          -0.419889          -4.712210
# 2     3.163030e-08            1.319242           2.497115          -2.112156
# 3     3.167723e-08            2.446075           1.069711          -2.761170
# 4     1.447435e-07            5.943155          -1.291092         -12.897732
#
#    non-boycott-diff  num_ratings
# 0        -37.509425         2538
# 1         -4.712210         8955
# 2         -2.112156        36884
# 3         -2.761170        26914
# 4        -12.897732         9316

# %%
df
# Out:
#               name  implicit_euclidean  implicit_cosine  explicit_euclidean  \
# 0         under 18            0.229271         0.534845            0.261837
# 1            18-24            0.134007         0.243307            0.139173
# 2            25-34            0.081984         0.070300            0.089426
# 3            35-44            0.076347         0.070187            0.089135
# 4            45-49            0.160902         0.196850            0.192490
# 5            50-55            0.158086         0.228398            0.187500
# 6              56+            0.134733         0.278362            0.146645
# 7              usa            0.035747         0.013189            0.034944
# 8           canada            0.124367         0.190501            0.131333
# 9          germany            0.247471         0.761705            0.224573
# 10  united kingdom            0.265304         0.605187            0.248197
# 11       australia            0.258564         0.535958            0.252118
# 12           spain            0.328014         0.788000            0.288102
# 13          france            0.419055         0.886080            0.392147
# 14        portugal            0.548163         0.654237            0.509249
# 15     netherlands            0.398843         0.691772            0.370499
# 16     switzerland            0.373325         0.848370            0.377896
# 17        malaysia            0.599568         0.562745            0.661002
# 18           italy            0.425332         0.831324            0.504168
# 19         austria            0.442785         0.828483            0.506654
# 20     new zealand            0.582436         0.746885            0.593953
# 21       singapore            0.614965         0.765454            0.639716
# 22         finland            0.624025         0.810297            0.759419
# 23         romania            0.768729         0.810490            1.173333
# 24      philippine            0.838762         0.765117            1.041613
# 25         ireland            0.561315         0.844900            0.664790
# 26           japan            0.779523         0.867288            0.863262
#
#     explicit_cosine  like-boycott-ratio  non-boycott-ratio  like-boycott-diff  \
# 0      2.759794e-07           23.759435           0.945829         -37.509425
# 1      7.781145e-08            7.369377          -0.419889          -4.712210
# 2      3.163030e-08            1.319242           2.497115          -2.112156
# 3      3.167723e-08            2.446075           1.069711          -2.761170
# 4      1.447435e-07            5.943155          -1.291092         -12.897732
# 5      1.384354e-07           18.714872          -0.857206         -19.151823
# 6      8.582746e-08            7.140852          -1.139240          -8.093726
# 7      4.828841e-09            1.018475           1.570782          -1.532556
# 8      6.939376e-08            3.450054           1.543136          -5.933126
# 9      1.999113e-07           26.095140           0.992001         -32.508058
# 10     2.478591e-07           18.470965           0.529199         -25.053275
# 11     2.550680e-07          136.994071           0.903718        -110.008110
# 12     3.303077e-07          304.702666           2.888988        -350.264771
# 13     6.169375e-07          -18.511628           5.865789         101.294563
# 14     1.044683e-06           -5.207104           4.541606          58.850917
# 15     5.504462e-07         -172.498631           3.882169        1295.628955
# 16     5.723386e-07           10.201332           8.249871        -117.648851
# 17     1.761285e-06         -444.638024          -0.089868         421.258199
# 18     1.022126e-06          459.325871          -0.932943         617.592583
# 19     1.033222e-06         -596.031852          -0.506007       -2027.309129
# 20     1.422970e-06          240.822851           2.844648       -1170.354322
# 21     1.646026e-06         -994.649013           0.266214        2287.621084
# 22     2.322927e-06         -125.395871           2.867218        1575.911575
# 23     5.548769e-06          181.799253           1.891120       -1462.350444
# 24     4.376058e-06        -4588.564068          -0.075360        1355.219932
# 25     1.777925e-06          -45.452683           4.768335        1272.755753
# 26     3.000144e-06          954.005512           2.464515      -11165.814663
#
#     non-boycott-diff  num_ratings
# 0         -37.509425         2538
# 1          -4.712210         8955
# 2          -2.112156        36884
# 3          -2.761170        26914
# 4         -12.897732         9316
# 5         -19.151823         9153
# 6          -8.093726         7177
# 7          -1.532556       106953
# 8          -5.933126        13608
# 9         -32.508058         2509
# 10        -25.053275         3383
# 11       -110.008110         1869
# 12       -350.264771         1374
# 13        101.294563          977
# 14         58.850917         1401
# 15       1295.628955          592
# 16       -117.648851          389
# 17        421.258199          958
# 18        617.592583          256
# 19      -2027.309129          292
# 20      -1170.354322          489
# 21       2287.621084          238
# 22       1575.911575          156
# 23      -1462.350444          165
# 24       1355.219932          211
# 25       1272.755753           96
# 26     -11165.814663          122

# %%
df[['name', 'num_ratings', 'like-boycott-ratio']][
#     (df.name.isin([
#         'male users', 'female users', 'power users', 'bottom 10% contributors'
#     ])) | (df.name.str.contains('fans'))
    df.num_ratings > 15000
].to_csv('selected_groups.csv', index=False, header=['Group Name', '# Ratings', 'Similar Users Effect Ratio'])

# %%
table_df = df[['name', 'num_ratings', 'like-boycott-ratio']][
        df.name.isin([
         'under 18', '18-24','25-34','35-44','45-49','50-55', '56+',
        
    ])
    #df.num_ratings > 150000
].rename(index=str, columns={'name': 'Name', 'num_ratings': '# Ratings', 'like-boycott-ratio': 'Similar User Effect Ratio'}
)

# %%
html = table_df.to_html(
    index=False,
    float_format='%.2f',
    columns=['Name', '# Ratings', 'Similar User Effect Ratio']
)
css = """
<style>
body {column-count: 1 !important;}
table {
    width: 2.5in; height:3in;
        font-size: x-small;
}
th, td, table {
    border-left: none;
    border-right: none;
    padding-left: 10px;
}
</style>
"""

with open('table.html', 'w') as f:
    f.write('<link rel="stylesheet" href="pubcss-acm-sigchi.css">' + css + html)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,15))
sns.barplot(y='name', x='implicit_euclidean', data=df, ax=axes[0,0])
sns.barplot(y='name', x='explicit_euclidean', data=df, ax=axes[0,1])
sns.barplot(y='name', x='implicit_cosine', data=df, ax=axes[1,0])
sns.barplot(y='name', x='explicit_cosine', data=df, ax=axes[1,1])
plt.show()

# %%
total = len(users_df.index)
print('total users', total)
# Out:
# total users 12293

# %%
from scipy.stats import pearsonr

#print(pearsonr(df['like-boycott-ratio'], df['non-boycott-ratio']))

print('\n===')
for distance in [
    'explicit_cosine', 'explicit_euclidean',
    'implicit_cosine', 'implicit_euclidean',
]:
    for ratio in [
        'like-boycott-ratio', 
        'non-boycott-ratio'
    ]:
        x = pearsonr(df[distance], df[ratio])
        print(distance, ratio)
        print(x)
        print('\n')
# Out:
# ===
# explicit_cosine like-boycott-ratio
# (-0.4093733710467628, 0.033968819456548054)
#
#
# explicit_cosine non-boycott-ratio
# (0.052838205484163805, 0.7935169343029704)
#
#
# explicit_euclidean like-boycott-ratio
# (-0.3696558118814357, 0.05772998009403634)
#
#
# explicit_euclidean non-boycott-ratio
# (0.13521023627558065, 0.501312232960287)
#
#
# implicit_cosine like-boycott-ratio
# (-0.10629690194603011, 0.5977088279311256)
#
#
# implicit_cosine non-boycott-ratio
# (0.4023460440306874, 0.03747223869503322)
#
#
# implicit_euclidean like-boycott-ratio
# (-0.35506015102540456, 0.0691587050428958)
#
#
# implicit_euclidean non-boycott-ratio
# (0.22107855008102759, 0.2677830237190469)

# %%
# NUM RATINGS VS LB RATIO

sns.regplot(x='num_ratings', y='like-boycott-ratio', data=df)
plt.show()
print(pearsonr(df['implicit_cosine'], df['like-boycott-ratio']))
#print(df[['implicit_cosine', 'like-boycott-ratio', 'name']].sort_values('implicit_cosine'))
# Out:
# (-0.10629690194603011, 0.5977088279311256)

# %%
#large_boycotts = df[df.num_ratings > 1e5]
filtered = df
sns.regplot(x='explicit_cosine', y='non-boycott-ratio', data=filtered)
plt.show()
print(pearsonr(filtered['explicit_cosine'], filtered['non-boycott-ratio']))
print(filtered[['implicit_cosine', 'num_ratings', 'like-boycott-ratio', 'name']].sort_values('implicit_cosine'))
# Out:
# (0.052838205484163805, 0.7935169343029704)
#     implicit_cosine  num_ratings  like-boycott-ratio            name
# 7          0.013189       106953            1.018475             usa
# 3          0.070187        26914            2.446075           35-44
# 2          0.070300        36884            1.319242           25-34
# 8          0.190501        13608            3.450054          canada
# 4          0.196850         9316            5.943155           45-49
# 5          0.228398         9153           18.714872           50-55
# 1          0.243307         8955            7.369377           18-24
# 6          0.278362         7177            7.140852             56+
# 0          0.534845         2538           23.759435        under 18
# 11         0.535958         1869          136.994071       australia
# 17         0.562745          958         -444.638024        malaysia
# 10         0.605187         3383           18.470965  united kingdom
# 14         0.654237         1401           -5.207104        portugal
# 15         0.691772          592         -172.498631     netherlands
# 20         0.746885          489          240.822851     new zealand
# 9          0.761705         2509           26.095140         germany
# 24         0.765117          211        -4588.564068      philippine
# 21         0.765454          238         -994.649013       singapore
# 12         0.788000         1374          304.702666           spain
# 22         0.810297          156         -125.395871         finland
# 23         0.810490          165          181.799253         romania
# 19         0.828483          292         -596.031852         austria
# 18         0.831324          256          459.325871           italy
# 25         0.844900           96          -45.452683         ireland
# 16         0.848370          389           10.201332     switzerland
# 26         0.867288          122          954.005512           japan
# 13         0.886080          977          -18.511628          france

# %%
# Implicit Cosine vs. LB Ratio
sns.set(style="darkgrid")
sns.set_color_codes("dark")

fig, ax = plt.subplots(1,1, figsize=(7, 3.5))
filtered = df[df.num_ratings >= 5000]
print('len, std, mean', len(df.num_ratings), np.std(df.num_ratings), np.mean(df.num_ratings))
#filtered = df

y = 'like-boycott-ratio'

sns.scatterplot(
    x='implicit_cosine', y=y, data=filtered,
    ax=ax, 
    #marker=".", 
    #line_kws={'alpha':.3},
    alpha=0.3
)

def label_point(x, y, val, ax, names):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        if str(point['val']) in names:
            ax.text(
                point['x'], point['y']+0.2, str(point['val']), 
            )
            ax.plot(point['x'], point['y'], 'bx')

label_point(
    filtered.implicit_cosine, filtered[y], filtered.name, plt.gca(),
    names=[
        'male users', 'female users', 'fans of film-noir', 'power users', 'under 18', 'artist',
        'fans of documentary', 'fans of horror',]
)  

plt.xlabel('Group Implicit Rating Cosine Distance from Centroid')
plt.title('Ratio of Strike Effect on Similar Users to Effect on Not Participating Users')
plt.ylabel('Effect Ratio')

ax.axhline(1, color='0.3', linestyle='--')
plt.savefig('implicitcosine_vs_lbratio.png', bbox_inches='tight', dpi=300)
plt.show()
print(pearsonr(filtered['implicit_cosine'], filtered[y]))
print(filtered[['implicit_cosine', 'num_ratings', y, 'name']].sort_values('implicit_cosine'))
# Out:
# len, std, mean 27 21051.74643358546 8776.851851851852
# (0.645459009083753, 0.0838890006666025)
#    implicit_cosine  num_ratings  like-boycott-ratio    name
# 7         0.013189       106953            1.018475     usa
# 3         0.070187        26914            2.446075   35-44
# 2         0.070300        36884            1.319242   25-34
# 8         0.190501        13608            3.450054  canada
# 4         0.196850         9316            5.943155   45-49
# 5         0.228398         9153           18.714872   50-55
# 1         0.243307         8955            7.369377   18-24
# 6         0.278362         7177            7.140852     56+
